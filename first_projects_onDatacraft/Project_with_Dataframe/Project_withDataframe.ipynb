# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Top250list = pd.read_excel(r"C:\Users\hhhme\Documents\GitHub\my-projects\first_projects_onDatacraft\Project_with_Dataframe\Liste_vonFilmen.xlsx")
Top250list.head(10)
# Out:
#    Ranking  Erics Top Filme  Gesehen  \
# 0        1              1.0        1
# 1        2              0.0        1
# 2        3              0.0        1
# 3        4              1.0        1
# 4        5              1.0        1
# 5        6              1.0        1
# 6        7              1.0        1
# 7        8              1.0        1
# 8        9              0.0        1
# 9       10              1.0        1
#
#                                                Title  Date  RunTime  \
# 0                           The Shawshank Redemption  1994      142
# 1                                      The Godfather  1972      175
# 2                             The Godfather: Part II  1974      202
# 3                                    The Dark Knight  2008      152
# 4                                       12 Angry Men  1957       96
# 5                                   Schindler's List  1993      195
# 6      The Lord of the Rings: The Return of the King  2003      201
# 7                                       Pulp Fiction  1994      154
# 8                     The Good, the Bad and the Ugly  1966      178
# 9  The Lord of the Rings: The Fellowship of the Ring  2001      178
#
#                        Genre  Rating              Director            Cast1  \
# 0                      Drama      93        Frank Darabont      Tim Robbins
# 1               Crime, Drama      92  Francis Ford Coppola    Marlon Brando
# 2               Crime, Drama      90  Francis Ford Coppola        Al Pacino
# 3       Action, Crime, Drama      90     Christopher Nolan   Christian Bale
# 4               Crime, Drama      90          Sidney Lumet      Henry Fonda
# 5  Biography, Drama, History      89      Steven Spielberg      Liam Neeson
# 6   Action, Adventure, Drama      89         Peter Jackson      Elijah Wood
# 7               Crime, Drama      89     Quentin Tarantino    John Travolta
# 8         Adventure, Western      88          Sergio Leone   Clint Eastwood
# 9   Action, Adventure, Drama      88         Peter Jackson      Elijah Wood
#
#                Cast2                Cast3               Cast4
# 0     Morgan Freeman           Bob Gunton      William Sadler
# 1          Al Pacino           James Caan        Diane Keaton
# 2     Robert De Niro        Robert Duvall        Diane Keaton
# 3       Heath Ledger        Aaron Eckhart       Michael Caine
# 4        Lee J. Cobb        Martin Balsam        John Fiedler
# 5      Ralph Fiennes         Ben Kingsley    Caroline Goodall
# 6    Viggo Mortensen         Ian McKellen       Orlando Bloom
# 7        Uma Thurman    Samuel L. Jackson        Bruce Willis
# 8        Eli Wallach        Lee Van Cleef        Aldo Giuffrè
# 9       Ian McKellen        Orlando Bloom           Sean Bean

# %% [markdown]
# ### Welche Genre sind am meisten vertreten

# %%
genre = Top250list["Genre"].value_counts() 
genre.plot.line(figsize=(10,7), rot = 45, lw=5)
plt.title("häufigsten Genres der 20. und 21. Jahrhunderten")
plt.xlabel("Genges")
plt.ylabel("Anzahl von Filmen dieser Genre")
# Out:
# Text(0, 0.5, 'Anzahl von Filmen dieser Genre')

# %%
genre

# pure Drama tritt also am meisten als Filmgenre
# Out:
# Drama                           20
# Crime, Drama                    14
# Biography, Drama, History        9
# Crime, Drama, Mystery            9
# Animation, Adventure, Comedy     8
#                                 ..
# Adventure, Comedy, Fantasy       1
# Comedy, Music, Romance           1
# Drama, Family, Sport             1
# Biography, Comedy, Crime         1
# Adventure, Family, Fantasy       1
# Name: Genre, Length: 108, dtype: int64

# %%
#Alternative:
Top250list["Genre"].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Biography, Drama, History', 'Action, Adventure, Drama',
#        'Adventure, Western', 'Drama, Romance',
#        'Action, Adventure, Sci-Fi', 'Action, Adventure, Fantasy',
#        'Action, Sci-Fi', 'Biography, Crime, Drama', 'Action, Drama',
#        'Crime, Drama, Mystery', 'Crime, Drama, Horror',
#        'Comedy, Drama, Family', 'Comedy, Drama, Romance', 'Drama, War',
#        'Adventure, Drama, Sci-Fi', 'Animation, Adventure, Family',
#        'Crime, Drama, Fantasy', 'Comedy, Drama, Thriller',
#        'Action, Drama, Mystery', 'Biography, Drama, Music',
#        'Adventure, Comedy, Sci-Fi', 'Horror, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Animation, Drama, War',
#        'Drama, Music', 'Crime, Drama, Thriller',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Thriller',
#        'Drama, Romance, War', 'Western', 'Mystery, Thriller',
#        'Horror, Sci-Fi', 'Drama, Mystery, War', 'Action, Adventure',
#        'Comedy, Drama, War', 'Drama, Western', 'Drama, Film-Noir',
#        'Drama, Horror', 'Animation, Action, Adventure', 'Comedy, War',
#        'Animation, Drama, Fantasy', 'Animation, Adventure, Comedy',
#        'Comedy, Drama', 'Adventure, Drama, War', 'Adventure, Sci-Fi',
#        'Drama, Thriller, War', 'Drama, Family',
#        'Mystery, Romance, Thriller', 'Crime, Mystery, Thriller',
#        'Drama, Mystery', 'Comedy, Musical, Romance',
#        'Adventure, Mystery, Thriller', 'Drama, Romance, Sci-Fi',
#        'Adventure, Biography, Drama', 'Action, Biography, Drama',
#        'Crime, Drama, Film-Noir', 'Drama, Sci-Fi', 'Crime, Sci-Fi',
#        'Comedy, Crime, Drama', 'Comedy, Crime', 'Action, Drama, War',
#        'Comedy, Romance', 'Action, Drama, Thriller', 'Action, Thriller',
#        'Adventure, Comedy, Fantasy', 'Comedy, Music, Romance',
#        'Drama, Family, Sport', 'Biography, Comedy, Crime',
#        'Adventure, Drama, History', 'Adventure, Drama, Western',
#        'Drama, Fantasy, War', 'Biography, Drama',
#        'Drama, Mystery, Romance', 'Biography, Drama, Sport',
#        'Animation, Comedy, Family', 'Action, Comedy, Crime',
#        'Crime, Thriller', 'Adventure, Comedy, Drama',
#        'Horror, Mystery, Sci-Fi', 'Drama, Fantasy, History',
#        'Film-Noir, Mystery, Thriller', 'Action, Drama, Sci-Fi',
#        'Action, Drama, Sport', 'Drama, History, Romance',
#        'Adventure, Comedy, Crime', 'Action, Adventure, Comedy',
#        'Action, Comedy, Romance', 'Drama, Thriller',
#        'Crime, Drama, History', 'Animation, Comedy, Drama',
#        'Comedy, Crime, Music', 'Comedy, Romance, War',
#        'Comedy, Crime, Sport', 'Adventure, Fantasy, Mystery',
#        'Drama, Sport', 'Drama, Romance, Thriller',
#        'Adventure, Drama, Thriller', 'Adventure, Drama',
#        'Biography, Drama, Family', 'Animation, Drama',
#        'Drama, Film-Noir, Mystery', 'Comedy',
#        'Animation, Adventure, Sci-Fi', 'Animation, Action, Drama',
#        'Adventure, Family, Fantasy'], dtype=object)

# %%
drama_genre = Top250list[Top250list.Genre.str.match(".*Drama.*")]
drama = drama_genre["Genre"].count()

crime_genre = Top250list[Top250list.Genre.str.match(".*Crime.*")]
crime = crime_genre["Genre"].count()

history_genre = Top250list[Top250list.Genre.str.match(".*History.*")]
history = history_genre["Genre"].count()

biography_genre = Top250list[Top250list.Genre.str.match(".*Biography.*")]
biography = biography_genre["Genre"].count()

adventure_genre = Top250list[Top250list.Genre.str.match(".*Adventure.*")]
adventure = adventure_genre["Genre"].count()

western_genre = Top250list[Top250list.Genre.str.match(".*Western.*")]
western= western_genre["Genre"].count()

mistery_genre = Top250list[Top250list.Genre.str.match(".*Mystery.*")]
mistery = mistery_genre["Genre"].count()

fantasy_genre = Top250list[Top250list.Genre.str.match(".*Fantasy.*")]
fantasy = fantasy_genre["Genre"].count()

war_genre = Top250list[Top250list.Genre.str.match(".*War.*")]
war = war_genre["Genre"].count()

family_genre = Top250list[Top250list.Genre.str.match(".*Family.*")]
family = family_genre["Genre"].count()

comedy_genre = Top250list[Top250list.Genre.str.match(".*Comedy.*")]
comedy = comedy_genre["Genre"].count()

scifi_genre = Top250list[Top250list.Genre.str.match(".*Sci-Fi.*")]
scifi = scifi_genre["Genre"].count()

horror_genre = Top250list[Top250list.Genre.str.match(".*Horror.*")]
horror = horror_genre["Genre"].count()

animation_genre = Top250list[Top250list.Genre.str.match(".*Animation.*")]
animation = animation_genre["Genre"].count()

thriller_genre = Top250list[Top250list.Genre.str.match(".*Thriller.*")]
thriller = thriller_genre["Genre"].count()

filmnoir_genre = Top250list[Top250list.Genre.str.match(".*Film-Noir.*")]
filmnoir = filmnoir_genre["Genre"].count()

sport_genre = Top250list[Top250list.Genre.str.match(".*Sport.*")]
sport = sport_genre["Genre"].count()

music_genre = Top250list[Top250list.Genre.str.match(".*Music.*")]
music = music_genre["Genre"].count()

musical_genre = Top250list[Top250list.Genre.str.match(".*Musical.*")]
musical = musical_genre["Genre"].count()

# %%
proGrafico = {"drama":drama, "crime":crime,"history":history,"biography":biography,"adventure":adventure,"western":western,"mistery":mistery,"fantasy":fantasy,"war":war,"family":family,"comedy":comedy,"scifi":scifi,"horror":horror,"animation":animation,"thriller":thriller,"filmnoir":filmnoir,"sport":sport,"music":music,"musical":musical}
pg = pd.Series(proGrafico)
pg
# Out:
# drama        183
# crime         57
# history       15
# biography     29
# adventure     55
# western        6
# mistery       32
# fantasy       11
# war           21
# family        12
# comedy        46
# scifi         20
# horror         5
# animation     22
# thriller      31
# filmnoir       4
# sport          6
# music          7
# musical        1
# dtype: int64

# %%
pg.plot.bar(figsize=(12,10), rot=50)
plt.title("häufigste Filmgenre")
plt.xlabel("Filmgenre")
plt.ylabel("Häufigkeit")
# Out:
# Text(0, 0.5, 'Häufigkeit')

# %% [markdown]
# #### Lieblingsfilmgenre

# %%
LbFilmG = Top250list.sort_values(by=["Rating"], ascending = False)
LbFilmG[["Genre","Rating","Title"]].head(10)

#Rang der 10 am meisten gerated Filme:
# Out:
#                          Genre  Rating  \
# 0                        Drama      93
# 139               Crime, Drama      93
# 1                 Crime, Drama      92
# 2                 Crime, Drama      90
# 3         Action, Crime, Drama      90
# 4                 Crime, Drama      90
# 5    Biography, Drama, History      89
# 6     Action, Adventure, Drama      89
# 7                 Crime, Drama      89
# 8           Adventure, Western      88
#
#                                              Title
# 0                         The Shawshank Redemption
# 139                                       Jai Bhim
# 1                                    The Godfather
# 2                           The Godfather: Part II
# 3                                  The Dark Knight
# 4                                     12 Angry Men
# 5                                 Schindler's List
# 6    The Lord of the Rings: The Return of the King
# 7                                     Pulp Fiction
# 8                   The Good, the Bad and the Ugly

# %% [markdown]
# #### Welche von den besten hat Eric sich noch nicht angeschaut?

# %%
LbFilmG[["Genre","Rating","Title","Gesehen"]].head(10)
# Out:
#                          Genre  Rating  \
# 0                        Drama      93
# 139               Crime, Drama      93
# 1                 Crime, Drama      92
# 2                 Crime, Drama      90
# 3         Action, Crime, Drama      90
# 4                 Crime, Drama      90
# 5    Biography, Drama, History      89
# 6     Action, Adventure, Drama      89
# 7                 Crime, Drama      89
# 8           Adventure, Western      88
#
#                                              Title  Gesehen
# 0                         The Shawshank Redemption        1
# 139                                       Jai Bhim        0
# 1                                    The Godfather        1
# 2                           The Godfather: Part II        1
# 3                                  The Dark Knight        1
# 4                                     12 Angry Men        1
# 5                                 Schindler's List        1
# 6    The Lord of the Rings: The Return of the King        1
# 7                                     Pulp Fiction        1
# 8                   The Good, the Bad and the Ugly        1

# %% [markdown]
# ### Wie viele Filme pro Jahrzehnte gibts in der Tabelle

# %%
lieblingsJahrgang = Top250list["Date"].value_counts() 
lieblingsJahrgang
# Out:
# 1995    8
# 1957    7
# 2004    6
# 2009    6
# 2018    6
#        ..
# 1944    1
# 1964    1
# 1921    1
# 1972    1
# 1934    1
# Name: Date, Length: 86, dtype: int64

# %%
lji = list(lieblingsJahrgang.index)
print(lji)
# Out:
# [1995, 1957, 2004, 2009, 2018, 2000, 2019, 1997, 1994, 2014, 1998, 2016, 2010, 1999, 2001, 2003, 1980, 1988, 1959, 2021, 2012, 1979, 2011, 2007, 2013, 2006, 1954, 1975, 1966, 2015, 2002, 1996, 2008, 1984, 1986, 2017, 1993, 1950, 1985, 1976, 2005, 1962, 1982, 1989, 1961, 1987, 1948, 1953, 1939, 1974, 1978, 1952, 2020, 1968, 1991, 1931, 1942, 1960, 1981, 1940, 1963, 1983, 1992, 1969, 1924, 1926, 1936, 1990, 1928, 1946, 1977, 1967, 1949, 1958, 1925, 1941, 1965, 1955, 1973, 1971, 1927, 1944, 1964, 1921, 1972, 1934]

# %%
zweitausendzehner = 0
zweitausender = 0
neunziger = 0
achtziger = 0
siebziger = 0
sechziger = 0
fünfziger = 0
vierziger = 0
dreiziger = 0
zwanziger = 0
for i in list(lji):
    if i <= 2022 and i >= 2010:
        zweitausendzehner += 1
    elif i < 2010 and i >= 2000:
        zweitausender += 1
    elif i < 2000 and i >= 1990:
        neunziger += 1
    elif i < 1990 and i >= 1980:
        achtziger += 1
    elif i < 1980 and i >= 1970:
        siebziger += 1
    elif i < 1970 and i >= 1960:
        sechziger += 1
    elif i < 1960 and i >= 1950:
        fünfziger += 1
    elif i < 1950 and i >= 1940:
        vierziger += 1
    elif i < 1940 and i >= 1930:
        dreiziger += 1
    elif i < 1930 and i >= 1920:
        zwanziger += 1
dictJahre = {"zweitausendzehner":zweitausendzehner, "zweitausender":zweitausender,"neunziger":neunziger,"achtziger":achtziger, "siebziger":siebziger, "sechziger":sechziger, "fünfziger":fünfziger, "vierziger":vierziger, "dreiziger":dreiziger, "zwanziger":zwanziger}
fürGrafik = pd.Series(dictJahre)     
fürGrafik
# Out:
# zweitausendzehner    12
# zweitausender        10
# neunziger            10
# achtziger            10
# siebziger             9
# sechziger            10
# fünfziger             8
# vierziger             7
# dreiziger             4
# zwanziger             6
# dtype: int64

# %%
fürGrafik.plot.bar(rot = 285) 
plt.title("Filmszene")
plt.xlabel("Ercheinungsdatum")
plt.ylabel("Anzahl an Filme")
# Out:
# Text(0, 0.5, 'Anzahl an Filme')

# %% [markdown]
# ### Unterschiede zwischen dem Top 250 und den Filmen die Eric gefallen haben

# %%
.sort_values(by=["Rating"], ascending = False)

# %%
TopEric = Top250list.groupby("Genre").sum().sort_values(by=["Erics Top Filme"], ascending = False)
TopEric[["Gesehen","Erics Top Filme"]].head(10)
# Out:
#                              Gesehen  Erics Top Filme
# Genre
# Drama                              8              5.0
# Action, Adventure, Sci-Fi          5              3.0
# Crime, Drama, Thriller             4              3.0
# Crime, Drama, Mystery              6              3.0
# Action, Adventure, Drama           5              3.0
# Drama, Mystery, Thriller           3              2.0
# Comedy, Drama                      2              2.0
# Biography, Drama, History          4              2.0
# Crime, Drama                       5              2.0
# Adventure, Fantasy, Mystery        1              1.0

# %%
TopEric = Top250list.groupby("Rating").sum()
TopEric[["Gesehen","Erics Top Filme"]]
# Out:
#         Gesehen  Erics Top Filme
# Rating
# 81           35             12.0
# 82           15              4.0
# 83           18              4.0
# 84           18              6.0
# 85           11              4.0
# 86            9              5.0
# 87            4              1.0
# 88            5              4.0
# 89            3              3.0
# 90            3              2.0
# 92            1              0.0
# 93            1              1.0

# %%
# Eric steht eher auf die Filme die mainstreamerweise zwischen 80 und 89 Punkte bekommen

# %%
topfilmeEric = Top250list.loc[Top250list["Erics Top Filme"] == 1.0]
topfilmeEric
# Out:
#      Ranking  Erics Top Filme  Gesehen  \
# 0          1              1.0        1
# 3          4              1.0        1
# 4          5              1.0        1
# 5          6              1.0        1
# 6          7              1.0        1
# 7          8              1.0        1
# 9         10              1.0        1
# 10        11              1.0        1
# 11        12              1.0        1
# 12        13              1.0        1
# 13        14              1.0        1
# 20        21              1.0        1
# 21        22              1.0        1
# 27        28              1.0        1
# 28        29              1.0        1
# 29        30              1.0        1
# 40        41              1.0        1
# 41        42              1.0        1
# 45        46              1.0        1
# 47        48              1.0        1
# 52        53              1.0        1
# 62        63              1.0        1
# 67        68              1.0        1
# 69        70              1.0        1
# 70        71              1.0        1
# 73        74              1.0        1
# 81        82              1.0        1
# 84        85              1.0        1
# 85        86              1.0        1
# 96        97              1.0        1
# 126      127              1.0        1
# 133      134              1.0        1
# 152      153              1.0        1
# 154      155              1.0        1
# 156      157              1.0        1
# 165      166              1.0        1
# 169      170              1.0        1
# 173      174              1.0        1
# 175      176              1.0        1
# 200      201              1.0        1
# 201      202              1.0        1
# 208      209              1.0        1
# 209      210              1.0        1
# 214      215              1.0        1
# 218      219              1.0        1
# 243      244              1.0        1
#
#                                                  Title  Date  RunTime  \
# 0                             The Shawshank Redemption  1994      142
# 3                                      The Dark Knight  2008      152
# 4                                         12 Angry Men  1957       96
# 5                                     Schindler's List  1993      195
# 6        The Lord of the Rings: The Return of the King  2003      201
# 7                                         Pulp Fiction  1994      154
# 9    The Lord of the Rings: The Fellowship of the Ring  2001      178
# 10                                          Fight Club  1999      139
# 11                                        Forrest Gump  1994      142
# 12                                           Inception  2010      148
# 13               The Lord of the Rings: The Two Towers  2002      179
# 20                                               Se7en  1995      127
# 21                            The Silence of the Lambs  1991      118
# 27                                        Interstellar  2014      169
# 28                                       Spirited Away  2001      125
# 29                                      The Green Mile  1999      189
# 40                              Grave of the Fireflies  1988       89
# 41                                  American History X  1998      119
# 45                                        The Departed  2006      151
# 47                                        The Prestige  2006      130
# 52                                               Alien  1979      117
# 62                              Avengers: Infinity War  2018      149
# 67                                   Princess Mononoke  1997      134
# 69                                               Joker  2019      122
# 70                                          Your Name.  2016      106
# 73                                              Aliens  1986      137
# 81                                     American Beauty  1999      122
# 84                                Inglourious Basterds  2009      153
# 85                                            Hamilton  2020      160
# 96                                 Requiem for a Dream  2000      102
# 126                                  L.A. Confidential  1997      138
# 133                    Monty Python and the Holy Grail  1975       91
# 152                                 My Neighbor Totoro  1988       86
# 154                                     Shutter Island  2010      138
# 156                             No Country for Old Men  2007      122
# 165                                    The Truman Show  1998      103
# 169                                 Memories of Murder  2003      132
# 173                                         Inside Out  2015       95
# 175                                              Fargo  1996       98
# 200                                               Room  2015      118
# 201                                          Gone Girl  2014      149
# 208                                   The Big Lebowski  1998      117
# 209                                 Dead Poets Society  1989      128
# 214       Harry Potter and the Deathly Hallows: Part 2  2011      130
# 218                                        Stand by Me  1986       89
# 243     Neon Genesis Evangelion: The End of Evangelion  1997       87
#
#                             Genre  Rating                         Director  \
# 0                           Drama      93                   Frank Darabont
# 3            Action, Crime, Drama      90                Christopher Nolan
# 4                    Crime, Drama      90                     Sidney Lumet
# 5       Biography, Drama, History      89                 Steven Spielberg
# 6        Action, Adventure, Drama      89                    Peter Jackson
# 7                    Crime, Drama      89                Quentin Tarantino
# 9        Action, Adventure, Drama      88                    Peter Jackson
# 10                          Drama      88                    David Fincher
# 11                 Drama, Romance      88                  Robert Zemeckis
# 12      Action, Adventure, Sci-Fi      88                Christopher Nolan
# 13       Action, Adventure, Drama      87                    Peter Jackson
# 20          Crime, Drama, Mystery      86                    David Fincher
# 21           Crime, Drama, Horror      86                   Jonathan Demme
# 27       Adventure, Drama, Sci-Fi      86                Christopher Nolan
# 28   Animation, Adventure, Family      86                   Hayao Miyazaki
# 29          Crime, Drama, Fantasy      86                   Frank Darabont
# 40          Animation, Drama, War      85                    Isao Takahata
# 41                          Drama      85                        Tony Kaye
# 45         Crime, Drama, Thriller      85                  Martin Scorsese
# 47       Drama, Mystery, Thriller      85                Christopher Nolan
# 52                 Horror, Sci-Fi      84                     Ridley Scott
# 62      Action, Adventure, Sci-Fi      84        Anthony Russo,  Joe Russo
# 67   Animation, Action, Adventure      84                   Hayao Miyazaki
# 69         Crime, Drama, Thriller      84                    Todd Phillips
# 70      Animation, Drama, Fantasy      84                   Makoto Shinkai
# 73      Action, Adventure, Sci-Fi      83                    James Cameron
# 81                          Drama      83                       Sam Mendes
# 84          Adventure, Drama, War      83                Quentin Tarantino
# 85      Biography, Drama, History      84                      Thomas Kail
# 96                          Drama      83                 Darren Aronofsky
# 126         Crime, Drama, Mystery      82                    Curtis Hanson
# 133    Adventure, Comedy, Fantasy      82      Terry Gilliam,  Terry Jones
# 152     Animation, Comedy, Family      82                   Hayao Miyazaki
# 154             Mystery, Thriller      82                  Martin Scorsese
# 156        Crime, Drama, Thriller      81           Ethan Coen,  Joel Coen
# 165                 Comedy, Drama      81                       Peter Weir
# 169         Crime, Drama, Mystery      81                     Bong Joon Ho
# 173  Animation, Adventure, Comedy      81  Pete Docter,  Ronnie Del Carmen
# 175               Crime, Thriller      81           Joel Coen,  Ethan Coen
# 200               Drama, Thriller      81                 Lenny Abrahamson
# 201      Drama, Mystery, Thriller      81                    David Fincher
# 208          Comedy, Crime, Sport      81           Joel Coen,  Ethan Coen
# 209                 Comedy, Drama      81                       Peter Weir
# 214   Adventure, Fantasy, Mystery      81                      David Yates
# 218              Adventure, Drama      81                       Rob Reiner
# 243      Animation, Action, Drama      81  Hideaki Anno,  Kazuya Tsurumaki
#
#                     Cast1                    Cast2                  Cast3  \
# 0             Tim Robbins           Morgan Freeman             Bob Gunton
# 3          Christian Bale             Heath Ledger          Aaron Eckhart
# 4             Henry Fonda              Lee J. Cobb          Martin Balsam
# 5             Liam Neeson            Ralph Fiennes           Ben Kingsley
# 6             Elijah Wood          Viggo Mortensen           Ian McKellen
# 7           John Travolta              Uma Thurman      Samuel L. Jackson
# 9             Elijah Wood             Ian McKellen          Orlando Bloom
# 10              Brad Pitt            Edward Norton              Meat Loaf
# 11              Tom Hanks             Robin Wright            Gary Sinise
# 12      Leonardo DiCaprio     Joseph Gordon-Levitt            Elliot Page
# 13            Elijah Wood             Ian McKellen        Viggo Mortensen
# 20         Morgan Freeman                Brad Pitt           Kevin Spacey
# 21           Jodie Foster          Anthony Hopkins     Lawrence A. Bonney
# 27    Matthew McConaughey            Anne Hathaway       Jessica Chastain
# 28          Daveigh Chase        Suzanne Pleshette             Miyu Irino
# 29              Tom Hanks    Michael Clarke Duncan            David Morse
# 40        Tsutomu Tatsumi          Ayano Shiraishi        Akemi Yamaguchi
# 41          Edward Norton           Edward Furlong       Beverly D'Angelo
# 45      Leonardo DiCaprio               Matt Damon         Jack Nicholson
# 47         Christian Bale             Hugh Jackman     Scarlett Johansson
# 52       Sigourney Weaver             Tom Skerritt              John Hurt
# 62      Robert Downey Jr.          Chris Hemsworth           Mark Ruffalo
# 67           Yôji Matsuda            Yuriko Ishida            Yûko Tanaka
# 69        Joaquin Phoenix           Robert De Niro            Zazie Beetz
# 70       Ryûnosuke Kamiki       Mone Kamishiraishi             Ryô Narita
# 73       Sigourney Weaver            Michael Biehn            Carrie Henn
# 81           Kevin Spacey           Annette Bening            Thora Birch
# 84              Brad Pitt             Diane Kruger               Eli Roth
# 85     Lin-Manuel Miranda             Phillipa Soo        Leslie Odom Jr.
# 96          Ellen Burstyn               Jared Leto      Jennifer Connelly
# 126          Kevin Spacey            Russell Crowe             Guy Pearce
# 133        Graham Chapman              John Cleese              Eric Idle
# 152        Hitoshi Takagi            Noriko Hidaka         Chika Sakamoto
# 154     Leonardo DiCaprio           Emily Mortimer           Mark Ruffalo
# 156       Tommy Lee Jones            Javier Bardem            Josh Brolin
# 165            Jim Carrey                Ed Harris           Laura Linney
# 169          Kang-ho Song           Kim Sang-kyung             Roe-ha Kim
# 173           Amy Poehler               Bill Hader            Lewis Black
# 175       William H. Macy        Frances McDormand          Steve Buscemi
# 200           Brie Larson           Jacob Tremblay          Sean Bridgers
# 201           Ben Affleck            Rosamund Pike    Neil Patrick Harris
# 208          Jeff Bridges             John Goodman         Julianne Moore
# 209        Robin Williams      Robert Sean Leonard            Ethan Hawke
# 214      Daniel Radcliffe              Emma Watson           Rupert Grint
# 218           Wil Wheaton            River Phoenix          Corey Feldman
# 243          Megumi Ogata       Megumi Hayashibara          Yûko Miyamura
#
#                         Cast4
# 0              William Sadler
# 3               Michael Caine
# 4                John Fiedler
# 5            Caroline Goodall
# 6               Orlando Bloom
# 7                Bruce Willis
# 9                   Sean Bean
# 10               Zach Grenier
# 11                Sally Field
# 12               Ken Watanabe
# 13              Orlando Bloom
# 20        Andrew Kevin Walker
# 21               Kasi Lemmons
# 27              Mackenzie Foy
# 28               Rumi Hiiragi
# 29                Bonnie Hunt
# 40          Yoshiko Shinohara
# 41              Jennifer Lien
# 45              Mark Wahlberg
# 47              Michael Caine
# 52        Veronica Cartwright
# 62                Chris Evans
# 67               Billy Crudup
# 69             Frances Conroy
# 70                   Aoi Yûki
# 73                Paul Reiser
# 81                Wes Bentley
# 84            Mélanie Laurent
# 85     Renée Elise Goldsberry
# 96              Marlon Wayans
# 126              Kim Basinger
# 133             Terry Gilliam
# 152            Shigesato Itoi
# 154              Ben Kingsley
# 156           Woody Harrelson
# 165             Noah Emmerich
# 169               Jae-ho Song
# 173              Mindy Kaling
# 175            Peter Stormare
# 200             Wendy Crewson
# 201               Tyler Perry
# 208             Steve Buscemi
# 209              Josh Charles
# 214            Michael Gambon
# 218           Jerry O'Connell
# 243          Kotono Mitsuishi

# %%
topfilmeEric["Rating"].plot.box()
# Out:
# <AxesSubplot:>

# %%
cast1 = Top250list["Cast1"].value_counts()
cast2 = Top250list["Cast2"].value_counts()
cast3 = Top250list["Cast3"].value_counts()
cast4 = Top250list["Cast4"].value_counts()

Schauspieler = pd.concat([cast1,cast2,cast3,cast4],axis = 0)

# %%
gg = Schauspieler.sort_values(ascending = False)
gg.head(20)
# Out:
#  Robert De Niro       6
#  Leonardo DiCaprio    5
#  Charles Chaplin      5
#  Tom Hanks            5
#  James Stewart        4
#  Christian Bale       4
#  Toshirô Mifune       4
#  Clint Eastwood       4
#   Harrison Ford       3
#   Robert De Niro      3
#   Mark Ruffalo        3
#   Carrie Fisher       3
#   Joe Pesci           3
#   Matt Damon          3
#  Al Pacino            3
#  Harrison Ford        3
#  Elijah Wood          3
#  Jack Nicholson       3
#  Kevin Spacey         3
#  Mark Hamill          3
# dtype: int64

# %%
gg.head(20).plot.bar(figsize=(10,5))
plt.title("Schauspieler die am meisten vertreten")
plt.xlabel("Schauspieler")
plt.ylabel("Häufigkeit deren Vertretung in Filmen")
# Out:
# Text(0, 0.5, 'Häufigkeit deren Vertretung in Filmen')

# %% [markdown]
# #### lange vs kurze Filme, welcher ist beliebter?

# %%
langeRunTime = Top250list.loc[Top250list["RunTime"] > 150]
langeRunTime[["RunTime","Rating"]].head(10).plot.bar(x="RunTime", y="Rating", figsize=(7,7), rot=0)
plt.title("lange Filme")
# Out:
# Text(0.5, 1.0, 'lange Filme')

# %%
kurzeRunTime = Top250list.loc[Top250list["RunTime"] < 100]

# %%
kurzeRunTime[["RunTime","Rating"]].head(10).plot.bar(x="RunTime", y="Rating", figsize=(7,7), rot=0)
plt.title("kurze Filme")
# Out:
# Text(0.5, 1.0, 'kurze Filme')
